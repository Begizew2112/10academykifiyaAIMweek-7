# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\Yibabe\Desktop\10academykifiyaAIMweek-7\data\scraped_data.csv')

# %%
df
# Out:
#         Channel Title Channel Username    ID  \
# 0    የጤና ወግ - የጤና መረጃ       @yetenaweg  1180
# 1    የጤና ወግ - የጤና መረጃ       @yetenaweg  1175
# 2    የጤና ወግ - የጤና መረጃ       @yetenaweg  1171
# 3    የጤና ወግ - የጤና መረጃ       @yetenaweg  1169
# 4    የጤና ወግ - የጤና መረጃ       @yetenaweg  1164
# ..                ...              ...   ...
# 726  የጤና ወግ - የጤና መረጃ       @yetenaweg     9
# 727  የጤና ወግ - የጤና መረጃ       @yetenaweg     8
# 728  የጤና ወግ - የጤና መረጃ       @yetenaweg     6
# 729  የጤና ወግ - የጤና መረጃ       @yetenaweg     5
# 730  የጤና ወግ - የጤና መረጃ       @yetenaweg     4
#
#                                                Message  \
# 0                                             ተጀምሯል !!
# 1    🤱በድህረ ወሊድ ጊዜ ምን ማወቅ አለብዎት??\n\n🌸ቀደምት የድህረ ወሊድ ...
# 2    💡በዚህ እሁድ በቴሌግራም ቀጥታ ስርጭት የእንቅልፍ ችግሮች የሚዳስስ ውይይ...
# 3    ⭐️ቲቢ(ቱበርኩሎሲስ) ምንድን ነው?\n\n💫ሳንባ ነቀርሳ (ቲቢ)በባክቴሪያ...
# 4    💥 ጉርምስና💥\n\n💥ጉርምስና ማለት በአስራዎቹ  የእድሜ ክልል መጀመሪያ ...
# ..                                                 ...
# ...

# %%
df['Media Path']
# Out:
# 0                         NaN
# 1                 Photo media
# 2                 Photo media
# 3                 Photo media
# 4                 Photo media
#                 ...
# 726    Error processing media
# 727                       NaN
# 728                       NaN
# 729               Photo media
# 730               Other media
# Name: Media Path, Length: 731, dtype: object

# %%
# Remove duplicates based on the 'ID' column
df1 = df.drop_duplicates(subset='ID', keep='first')
print(f"Removed {len(df) - len(df1)} duplicate rows")
# Out:
# Removed 0 duplicate rows

# %%
# Fill NaN values with "Unknown media"
df1['Media Path'].fillna("Unknown media", inplace=True)

# %%
df1.head()
# Out:
#       Channel Title Channel Username    ID  \
# 0  የጤና ወግ - የጤና መረጃ       @yetenaweg  1180
# 1  የጤና ወግ - የጤና መረጃ       @yetenaweg  1175
# 2  የጤና ወግ - የጤና መረጃ       @yetenaweg  1171
# 3  የጤና ወግ - የጤና መረጃ       @yetenaweg  1169
# 4  የጤና ወግ - የጤና መረጃ       @yetenaweg  1164
#
#                                              Message  \
# 0                                           ተጀምሯል !!
# 1  🤱በድህረ ወሊድ ጊዜ ምን ማወቅ አለብዎት??\n\n🌸ቀደምት የድህረ ወሊድ ...
# 2  💡በዚህ እሁድ በቴሌግራም ቀጥታ ስርጭት የእንቅልፍ ችግሮች የሚዳስስ ውይይ...
# 3  ⭐️ቲቢ(ቱበርኩሎሲስ) ምንድን ነው?\n\n💫ሳንባ ነቀርሳ (ቲቢ)በባክቴሪያ...
# 4  💥 ጉርምስና💥\n\n💥ጉርምስና ማለት በአስራዎቹ  የእድሜ ክልል መጀመሪያ ...
#
#                        Date     Media Path
# 0 2024-10-06 15:03:40+00:00  Unknown media
# 1 2024-10-04 13:14:16+00:00    Photo media
# 2 2024-10-03 05:09:38+00:00    Photo media
# 3 2024-10-02 07:04:03+00:00    Photo media
# 4 2024-09-25 06:38:28+00:00    Photo media

# %%
# Convert 'Date' column to a standard datetime format
df1['Date'] = pd.to_datetime(df1['Date'], errors='coerce')

# Convert text to lowercase (if needed)
df1['Message'] =df1['Message'].str.lower()

# Strip unnecessary whitespace from text fields
df1['Message'] = df1['Message'].str.strip()

# %%
df1.head()
# Out:
#       Channel Title Channel Username    ID  \
# 0  የጤና ወግ - የጤና መረጃ       @yetenaweg  1180
# 1  የጤና ወግ - የጤና መረጃ       @yetenaweg  1175
# 2  የጤና ወግ - የጤና መረጃ       @yetenaweg  1171
# 3  የጤና ወግ - የጤና መረጃ       @yetenaweg  1169
# 4  የጤና ወግ - የጤና መረጃ       @yetenaweg  1164
#
#                                              Message  \
# 0                                           ተጀምሯል !!
# 1  🤱በድህረ ወሊድ ጊዜ ምን ማወቅ አለብዎት??\n\n🌸ቀደምት የድህረ ወሊድ ...
# 2  💡በዚህ እሁድ በቴሌግራም ቀጥታ ስርጭት የእንቅልፍ ችግሮች የሚዳስስ ውይይ...
# 3  ⭐️ቲቢ(ቱበርኩሎሲስ) ምንድን ነው?\n\n💫ሳንባ ነቀርሳ (ቲቢ)በባክቴሪያ...
# 4  💥 ጉርምስና💥\n\n💥ጉርምስና ማለት በአስራዎቹ  የእድሜ ክልል መጀመሪያ ...
#
#                        Date     Media Path
# 0 2024-10-06 15:03:40+00:00  Unknown media
# 1 2024-10-04 13:14:16+00:00    Photo media
# 2 2024-10-03 05:09:38+00:00    Photo media
# 3 2024-10-02 07:04:03+00:00    Photo media
# 4 2024-09-25 06:38:28+00:00    Photo media

# %%
import re
# Define a Function to Remove Emojis
def remove_emojis(text):
    # Define a regex pattern for emojis
    emoji_pattern = re.compile(
        "["
        "\U0001F600-\U0001F64F"  # emoticons
        "\U0001F300-\U0001F5FF"  # symbols & pictographs
        "\U0001F680-\U0001F6FF"  # transport & map symbols
        "\U0001F700-\U0001F77F"  # alchemical symbols
        "\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
        "\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
        "\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
        "\U0001FA00-\U0001FA6F"  # Chess Symbols
        "\U00002702-\U000027B0"  # Dingbats
        "\U000024C2-\U0001F251"
        "]+",
        flags=re.UNICODE
    )
    return emoji_pattern.sub(r'', text)  # Remove emojis

# %%
#Apply the Function to THE DataFrame
df1['cleaned_message'] = df1['Message'].apply(remove_emojis)

# %%
# Check the results
df1['cleaned_message'].head()
# Out:
# 0                                             ተጀምሯል !!
# 1    በድህረ ወሊድ ጊዜ ምን ማወቅ አለብዎት??\n\nቀደምት የድህረ ወሊድ ጊዜ...
# 2    በዚህ እሁድ በቴሌግራም ቀጥታ ስርጭት የእንቅልፍ ችግሮች የሚዳስስ ውይይት...
# 3    ቲቢ(ቱበርኩሎሲስ) ምንድን ነው?\n\nሳንባ ነቀርሳ (ቲቢ)በባክቴሪያ የሚ...
# 4     ጉርምስና\n\nጉርምስና ማለት በአስራዎቹ  የእድሜ ክልል መጀመሪያ ውስጥ...
# Name: cleaned_message, dtype: object

# %%
df2 = df1.drop(['Message','Channel Username'],axis= 'columns')

# %%
df3 = df2.drop(['Channel Username'],axis= 'columns')

# %%
df3
# Out:
#         Channel Title    ID                      Date              Media Path  \
# 0    የጤና ወግ - የጤና መረጃ  1180 2024-10-06 15:03:40+00:00           Unknown media
# 1    የጤና ወግ - የጤና መረጃ  1175 2024-10-04 13:14:16+00:00             Photo media
# 2    የጤና ወግ - የጤና መረጃ  1171 2024-10-03 05:09:38+00:00             Photo media
# 3    የጤና ወግ - የጤና መረጃ  1169 2024-10-02 07:04:03+00:00             Photo media
# 4    የጤና ወግ - የጤና መረጃ  1164 2024-09-25 06:38:28+00:00             Photo media
# ..                ...   ...                       ...                     ...
# 726  የጤና ወግ - የጤና መረጃ     9 2020-02-18 12:02:17+00:00  Error processing media
# 727  የጤና ወግ - የጤና መረጃ     8 2020-02-17 21:45:20+00:00           Unknown media
# 728  የጤና ወግ - የጤና መረጃ     6 2020-02-17 21:42:39+00:00           Unknown media
# 729  የጤና ወግ - የጤና መረጃ     5 2020-02-17 20:58:59+00:00             Photo media
# 730  የጤና ወግ - የጤና መረጃ     4 2020-02-17 20:55:46+00:00             Other media
#
# ...
